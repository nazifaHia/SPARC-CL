# %%
import os
import numpy as np
import tensorflow as tf
import tensorflow_model_optimization as tfmot
print(tfmot.__version__)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
# Out:
# 0.8.1

# %%
IMG_SIZE = 160
FEATURE_DIM = 64
PROJECTION_DIM = 64
BATCH_SIZE = 32
EPOCHS = 40   # or whatever epoch count you're planning
TEMPERATURE = 0.1
NUM_DOMAINS = 2


SOURCE_DIR = '/media/iot-lab/Projects/Nazifa/Unlearning/feature_unlearning/PlantVillage-Dataset/raw/segmented'
TARGET_DIR = '/media/iot-lab/Projects/Nazifa/Unlearning/feature_unlearning/RiceDiseases-DataSet'

SOURCE_CLASSES = [
    "Tomato___Bacterial_spot",
    "Corn_(maize)___Northern_Leaf_Blight",
    "Potato___Early_blight",
    "Corn_(maize)___Cercospora_leaf_spot_Gray_leaf_spot",
    "Tomato___Septoria_leaf_spot",
    "Strawberry___Leaf_scorch"
]

# Ensure only actual class directories are included, excluding hidden ones
TARGET_CLASSES = sorted([d for d in os.listdir(TARGET_DIR)
                         if os.path.isdir(os.path.join(TARGET_DIR, d)) and not d.startswith('.')])

# %%
# IMG_SIZE = 96
# FEATURE_DIM = 64
# PROJECTION_DIM = 64

# base = tf.keras.applications.MobileNetV2(
#     input_shape=(IMG_SIZE, IMG_SIZE, 3),
#     include_top=False,
#     weights="imagenet",
#     alpha=0.75
# )
# print("Final feature map shape:", base.output_shape)   # check this isn't degenerate (1x1 or smaller)
# print("Total params:", base.count_params())
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.75_96_no_top.h5
# 5903360/5903360 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Final feature map shape: (None, 3, 3, 1280)
# Total params: 1382064

# %%
# ===============================================================
# AUGMENTATIONS (ENHANCED)
# ===============================================================
def strong_aug(x):
    x = tf.image.random_flip_left_right(x)
    x = tf.image.random_flip_up_down(x)
    x = tf.image.random_brightness(x, 0.8)
    x = tf.image.random_contrast(x, 0.5, 1.5)
    x = tf.image.random_saturation(x, 0.5, 1.5)
    # keep hue removed — that was correct
    return tf.clip_by_value(x, 0, 1)

# Simplified create_views to apply strong augmentation to both views for contrastive learning
def create_views(img):
    img = tf.cast(img, tf.float32) / 255.0
    return strong_aug(img), strong_aug(img)

# %%
# ===============================================================
# GENERATOR
# ===============================================================
def combined_generator(batch_size=BATCH_SIZE):
    datagen = ImageDataGenerator()

    s_gen = datagen.flow_from_directory(
        SOURCE_DIR, classes=SOURCE_CLASSES,
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=batch_size // 2, shuffle=True, class_mode=None
    )

    t_gen = datagen.flow_from_directory(
        TARGET_DIR,
        target_size=(IMG_SIZE, IMG_SIZE),
        batch_size=batch_size // 2, shuffle=True, class_mode=None
    )

    while True:
        xs = next(s_gen)
        xt = next(t_gen)

        X = np.concatenate([xs, xt], axis=0)

        domain = tf.concat([
            tf.zeros(xs.shape[0], dtype=tf.int32),
            tf.ones(xt.shape[0], dtype=tf.int32)
        ], axis=0)

        v1, v2 = [], []
        for img in X:
            a, b = create_views(img) # Call simplified create_views
            v1.append(a)
            v2.append(b)

        yield (tf.stack(v1), tf.stack(v2)), domain

# %%
# ===============================================================
# ENCODER (SIMPLIFIED & STRONGER)
# TinyML config: MobileNetV2, alpha=0.75, reduced input resolution
# ===============================================================
def build_encoder():
    base = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights="imagenet",
        alpha=0.75
    )
    x = layers.GlobalAveragePooling2D()(base.output)
    x = layers.Dense(FEATURE_DIM, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(FEATURE_DIM)(x)
    return models.Model(base.input, x)

# %%
#================================================================
# UNLEARNING
# ===============================================================
class AdaptiveMMDUnlearning(tf.keras.layers.Layer):
    def __init__(self, dim, num_domains, k=2, sigma=1.0, temperature=0.5):
        super().__init__()
        self.dim = dim
        self.num_domains = num_domains
        self.k = k
        self.sigma = sigma
        self.temperature = temperature

    def build(self, _):
        self.domain_basis = self.add_weight(
            shape=(self.num_domains, self.k, self.dim),
            initializer="orthogonal",
            trainable=True,
            name="domain_basis"
        )
        self.lambda_unlearn = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(0.3),
            trainable=True,
            constraint=tf.keras.constraints.MinMaxNorm(min_value=0.1,max_value=0.6),
            name="lambda_unlearn"
        )
        self.log_sigma = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(0.0),
            trainable=True,
            name="log_sigma"
        )

    def _mmd_gate(self, f, d):
        sigma = tf.exp(self.log_sigma)
        f0 = tf.boolean_mask(f, tf.equal(d, 0))
        f1 = tf.boolean_mask(f, tf.equal(d, 1))

        batch_safe = tf.logical_and(
            tf.greater(tf.shape(f0)[0], 1),
            tf.greater(tf.shape(f1)[0], 1)
        )

        def compute_gate():
            mu0 = tf.reduce_mean(f0, axis=0)
            mu1 = tf.reduce_mean(f1, axis=0)
            diff_sq = tf.square(mu0 - mu1)
            pooled_var = (tf.math.reduce_variance(f0, axis=0) +
                          tf.math.reduce_variance(f1, axis=0)) / 2.0 + 1e-8
            discrepancy = diff_sq / pooled_var
            return tf.exp(-discrepancy / (2.0 * tf.square(sigma)))

        gate = tf.cond(
            batch_safe,
            compute_gate,
            lambda: tf.ones(self.dim, dtype=f.dtype)
        )
        return tf.expand_dims(gate, axis=0)

    def _ocm_projection(self, f_norm, d):
        B = tf.math.l2_normalize(tf.gather(self.domain_basis, d), axis=2)
        f_exp = tf.expand_dims(f_norm, axis=1)
        proj_coeff = tf.clip_by_value(
            tf.reduce_sum(f_exp * B, axis=2, keepdims=True), -1.0, 1.0
        )
        return tf.reduce_sum(proj_coeff * B, axis=1)

    def call(self, f, d, training=None):
        f_norm = tf.math.l2_normalize(f, axis=1)
        gate = self._mmd_gate(f_norm, d)
        proj = self._ocm_projection(f_norm, d)
        f_clean = f_norm - self.lambda_unlearn * (proj * (1.0 - gate))
        return tf.math.l2_normalize(f_clean, axis=1)

    def gate_entropy_loss(self, f, d):
        gate = self._mmd_gate(f, d)
        entropy = -gate * tf.math.log(gate + 1e-8) \
                  - (1 - gate) * tf.math.log(1 - gate + 1e-8)
        return tf.reduce_mean(entropy)

# %%
# ===============================================================
# LOSSES
# ===============================================================
def nt_xent(z1, z2, temp=0.1):
    z1 = tf.math.l2_normalize(z1, axis=1)
    z2 = tf.math.l2_normalize(z2, axis=1)

    z = tf.concat([z1, z2], axis=0)
    sim = tf.matmul(z, z, transpose_b=True) / temp

    mask = tf.eye(tf.shape(z)[0])
    sim -= mask * 1e9

    bs = tf.shape(z1)[0]
    labels = tf.concat([tf.range(bs, 2*bs), tf.range(bs)], axis=0)

    loss = tf.keras.losses.sparse_categorical_crossentropy(labels, sim, from_logits=True)
    return tf.reduce_mean(loss)

# %%
# ===============================================================
# MODEL (UPDATED FOR PSEUDO-LABELING)
# Removed GRL and domain_head for pseudo-labeling approach
# ===============================================================
class FullModel(tf.keras.Model):
    def __init__(self, enc):
        super().__init__()
        self.enc = enc
       
        self.proj = models.Sequential([
            layers.Dense(PROJECTION_DIM, activation='relu'),
            layers.Dense(PROJECTION_DIM)
        ])
        self.un = AdaptiveMMDUnlearning(
            dim=FEATURE_DIM,
            num_domains=NUM_DOMAINS,
            k=1
        )

    def train_step(self, data):
        (v1, v2), d = data

        with tf.GradientTape() as tape:
            h1 = self.enc(v1, training=True)
            h2 = self.enc(v2, training=True)

            h1_unlearned = self.un(h1, d, training=True)
            h2_unlearned = self.un(h2, d, training=True)

            z1 = self.proj(h1_unlearned)
            z2 = self.proj(h2_unlearned)

            loss_c = nt_xent(z1, z2)

            loss_gate = (
                self.un.gate_entropy_loss(h1_unlearned, d) +
                self.un.gate_entropy_loss(h2_unlearned, d)
            ) / 2.0

            loss = 1.0 * loss_c + 0.001 * loss_gate

        trainable_vars = (self.enc.trainable_variables +
                          self.un.trainable_variables +
                          self.proj.trainable_variables)

        grads = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(grads, trainable_vars))

        gate_vals = self.un._mmd_gate(h1_unlearned, d)

        return {
            "total": loss,
            "contrastive": loss_c,
            "gate_entropy": loss_gate,
            "lambda_unlearn": self.un.lambda_unlearn[0],
            "sigma": tf.exp(self.un.log_sigma)[0],
            "gate_mean": tf.reduce_mean(gate_vals),
            "gate_std": tf.math.reduce_std(gate_vals)
        }

# %%
# ===============================================================
# TRAIN
# ===============================================================
enc = build_encoder()

# 🔥 IMPORTANT: UNFREEZE ALL ENCODER LAYERS for full fine-tuning during DA
for layer in enc.layers:
    layer.trainable = True

model = FullModel(enc)
model.compile(optimizer=tf.keras.optimizers.Adam(5e-5)) # Slightly reduced learning rate

gen = combined_generator()

print("🚀 Training with stronger settings and pseudo-labeling for improved accuracy...")
model.fit(gen, steps_per_epoch=200, epochs=EPOCHS, verbose=1)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.75_160_no_top.h5
# 5903360/5903360 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# 🚀 Training with stronger settings and pseudo-labeling for improved accuracy...
# Found 6992 images belonging to 6 classes.
# Found 552 images belonging to 4 classes.
# Epoch 1/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 261s 1s/step - contrastive: 1.9751 - gate_entropy: 0.3758 - gate_mean: 0.7551 - gate_std: 0.2506 - lambda_unlearn: 0.3005 - sigma: 1.0000 - total: 1.9755
# Epoch 2/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 242s 1s/step - contrastive: 1.5417 - gate_entropy: 0.3762 - gate_mean: 0.7301 - gate_std: 0.2671 - lambda_unlearn: 0.3005 - sigma: 1.0005 - total: 1.5421
# Epoch 3/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - contrastive: 1.4084 - gate_entropy: 0.3316 - gate_mean: 0.7979 - gate_std: 0.2335 - lambda_unlearn: 0.3004 - sigma: 1.0013 - total: 1.4087
# Epoch 4/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 1.3991 - gate_entropy: 0.3737 - gate_mean: 0.7790 - gate_std: 0.2202 - lambda_unlearn: 0.3016 - sigma: 1.0013 - total: 1.3995
# Epoch 5/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - contrastive: 0.7219 - gate_entropy: 0.3504 - gate_mean: 0.7771 - gate_std: 0.2546 - lambda_unlearn: 0.3018 - sigma: 1.0015 - total: 0.7222
# Epoch 6/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - contrastive: 0.9260 - gate_entropy: 0.3419 - gate_mean: 0.7799 - gate_std: 0.2483 - lambda_unlearn: 0.3021 - sigma: 1.0020 - total: 0.9264
# Epoch 7/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - contrastive: 0.8327 - gate_entropy: 0.3580 - gate_mean: 0.8004 - gate_std: 0.2200 - lambda_unlearn: 0.3037 - sigma: 1.0009 - total: 0.8331
# Epoch 8/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - contrastive: 0.6383 - gate_entropy: 0.3309 - gate_mean: 0.7546 - gate_std: 0.2756 - lambda_unlearn: 0.3051 - sigma: 1.0000 - total: 0.6386
# Epoch 9/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.8425 - gate_entropy: 0.3823 - gate_mean: 0.7381 - gate_std: 0.2722 - lambda_unlearn: 0.3081 - sigma: 0.9976 - total: 0.8429
# Epoch 10/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.5576 - gate_entropy: 0.3479 - gate_mean: 0.7656 - gate_std: 0.2552 - lambda_unlearn: 0.3104 - sigma: 0.9957 - total: 0.5579
# Epoch 11/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.7106 - gate_entropy: 0.3634 - gate_mean: 0.7574 - gate_std: 0.2553 - lambda_unlearn: 0.3133 - sigma: 0.9934 - total: 0.7110
# Epoch 12/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.8358 - gate_entropy: 0.3270 - gate_mean: 0.7910 - gate_std: 0.2478 - lambda_unlearn: 0.3156 - sigma: 0.9914 - total: 0.8361
# Epoch 13/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3956 - gate_entropy: 0.3422 - gate_mean: 0.7933 - gate_std: 0.2328 - lambda_unlearn: 0.3165 - sigma: 0.9910 - total: 0.3959
# Epoch 14/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.8749 - gate_entropy: 0.3599 - gate_mean: 0.7752 - gate_std: 0.2372 - lambda_unlearn: 0.3172 - sigma: 0.9911 - total: 0.8753
# Epoch 15/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3021 - gate_entropy: 0.3488 - gate_mean: 0.7970 - gate_std: 0.2429 - lambda_unlearn: 0.3189 - sigma: 0.9899 - total: 0.3025
# Epoch 16/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3832 - gate_entropy: 0.3138 - gate_mean: 0.8020 - gate_std: 0.2462 - lambda_unlearn: 0.3209 - sigma: 0.9885 - total: 0.3835
# Epoch 17/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4887 - gate_entropy: 0.3346 - gate_mean: 0.7889 - gate_std: 0.2411 - lambda_unlearn: 0.3220 - sigma: 0.9881 - total: 0.4890
# Epoch 18/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4277 - gate_entropy: 0.3603 - gate_mean: 0.7741 - gate_std: 0.2463 - lambda_unlearn: 0.3227 - sigma: 0.9877 - total: 0.4281
# Epoch 19/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.6516 - gate_entropy: 0.3468 - gate_mean: 0.8160 - gate_std: 0.2019 - lambda_unlearn: 0.3251 - sigma: 0.9857 - total: 0.6519
# Epoch 20/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3134 - gate_entropy: 0.3367 - gate_mean: 0.8116 - gate_std: 0.2166 - lambda_unlearn: 0.3260 - sigma: 0.9853 - total: 0.3137
# Epoch 21/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3129 - gate_entropy: 0.3011 - gate_mean: 0.8386 - gate_std: 0.1972 - lambda_unlearn: 0.3285 - sigma: 0.9837 - total: 0.3132
# Epoch 22/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.8016 - gate_entropy: 0.3347 - gate_mean: 0.7783 - gate_std: 0.2670 - lambda_unlearn: 0.3298 - sigma: 0.9830 - total: 0.8020
# Epoch 23/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4687 - gate_entropy: 0.3447 - gate_mean: 0.7818 - gate_std: 0.2466 - lambda_unlearn: 0.3312 - sigma: 0.9822 - total: 0.4690
# Epoch 24/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.6587 - gate_entropy: 0.3383 - gate_mean: 0.7982 - gate_std: 0.2341 - lambda_unlearn: 0.3331 - sigma: 0.9810 - total: 0.6590
# Epoch 25/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3863 - gate_entropy: 0.3444 - gate_mean: 0.7775 - gate_std: 0.2514 - lambda_unlearn: 0.3346 - sigma: 0.9799 - total: 0.3867
# Epoch 26/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4418 - gate_entropy: 0.3285 - gate_mean: 0.7887 - gate_std: 0.2444 - lambda_unlearn: 0.3375 - sigma: 0.9775 - total: 0.4421
# Epoch 27/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.5232 - gate_entropy: 0.3673 - gate_mean: 0.7617 - gate_std: 0.2577 - lambda_unlearn: 0.3387 - sigma: 0.9771 - total: 0.5235
# Epoch 28/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.6404 - gate_entropy: 0.3459 - gate_mean: 0.7658 - gate_std: 0.2619 - lambda_unlearn: 0.3409 - sigma: 0.9755 - total: 0.6407
# Epoch 29/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.7349 - gate_entropy: 0.3486 - gate_mean: 0.7691 - gate_std: 0.2581 - lambda_unlearn: 0.3421 - sigma: 0.9750 - total: 0.7352
# Epoch 30/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.2685 - gate_entropy: 0.3484 - gate_mean: 0.7563 - gate_std: 0.2599 - lambda_unlearn: 0.3445 - sigma: 0.9731 - total: 0.2689
# Epoch 31/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3330 - gate_entropy: 0.3069 - gate_mean: 0.7995 - gate_std: 0.2561 - lambda_unlearn: 0.3481 - sigma: 0.9708 - total: 0.3333
# Epoch 32/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.5094 - gate_entropy: 0.3060 - gate_mean: 0.8114 - gate_std: 0.2364 - lambda_unlearn: 0.3508 - sigma: 0.9690 - total: 0.5097
# Epoch 33/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3780 - gate_entropy: 0.3196 - gate_mean: 0.7951 - gate_std: 0.2563 - lambda_unlearn: 0.3552 - sigma: 0.9657 - total: 0.3783
# Epoch 34/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.2941 - gate_entropy: 0.3243 - gate_mean: 0.8025 - gate_std: 0.2384 - lambda_unlearn: 0.3581 - sigma: 0.9628 - total: 0.2944
# Epoch 35/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.0908 - gate_entropy: 0.3159 - gate_mean: 0.7955 - gate_std: 0.2604 - lambda_unlearn: 0.3618 - sigma: 0.9603 - total: 0.0911
# Epoch 36/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.5736 - gate_entropy: 0.2994 - gate_mean: 0.7942 - gate_std: 0.2607 - lambda_unlearn: 0.3645 - sigma: 0.9580 - total: 0.5739
# Epoch 37/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 226s 1s/step - contrastive: 0.2462 - gate_entropy: 0.3263 - gate_mean: 0.7765 - gate_std: 0.2666 - lambda_unlearn: 0.3680 - sigma: 0.9549 - total: 0.2465
# Epoch 38/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4998 - gate_entropy: 0.3530 - gate_mean: 0.7497 - gate_std: 0.2748 - lambda_unlearn: 0.3716 - sigma: 0.9521 - total: 0.5001
# Epoch 39/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.9949 - gate_entropy: 0.3402 - gate_mean: 0.8189 - gate_std: 0.2160 - lambda_unlearn: 0.3747 - sigma: 0.9497 - total: 0.9952
# Epoch 40/40
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.2674 - gate_entropy: 0.3285 - gate_mean: 0.7815 - gate_std: 0.2669 - lambda_unlearn: 0.3782 - sigma: 0.9471 - total: 0.2677

# %%
#===============================================================
# SAVE ENCODER
# ===============================================================
model.enc.save("MV2_Encoder_alpha75_160image_Jul11.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
(v1, v2), d = next(gen)
h1 = model.enc(v1, training=False)
h1_norm = tf.math.l2_normalize(h1, axis=1)

sim_matrix = tf.matmul(h1_norm, h1_norm, transpose_b=True)
print("Mean pairwise similarity:", tf.reduce_mean(sim_matrix).numpy())
print("Std of embeddings across batch:", tf.math.reduce_std(h1, axis=0).numpy().mean())
# Out:
# Mean pairwise similarity: 0.021849431
# Std of embeddings across batch: 1.1904771

# %%
print(type(enc))
print(hasattr(enc, '_is_graph_network'), getattr(enc, '_is_graph_network', None))
# Out:
# <class 'keras.src.models.functional.Functional'>
# False None

# %%
enc = tf.keras.models.load_model("MV2_Encoder_alpha75_160image_Jul11.h5", compile=False)

model = FullModel(enc)   # rewrap in your FullModel/unlearning setup
model.compile(optimizer=tf.keras.optimizers.Adam(5e-5))

# continue for 20 more epochs to reach 40 total
model.fit(gen, steps_per_epoch=200, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - contrastive: 0.6906 - gate_entropy: 0.3207 - gate_mean: 0.7546 - gate_std: 0.2829 - lambda_unlearn: 0.3019 - sigma: 0.9992 - total: 0.6909
# Epoch 2/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - contrastive: 0.4187 - gate_entropy: 0.3251 - gate_mean: 0.7742 - gate_std: 0.2633 - lambda_unlearn: 0.3030 - sigma: 0.9989 - total: 0.4191
# Epoch 3/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - contrastive: 0.3537 - gate_entropy: 0.3169 - gate_mean: 0.7872 - gate_std: 0.2682 - lambda_unlearn: 0.3032 - sigma: 0.9997 - total: 0.3540
# Epoch 4/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - contrastive: 0.2433 - gate_entropy: 0.3207 - gate_mean: 0.7824 - gate_std: 0.2623 - lambda_unlearn: 0.3039 - sigma: 0.9997 - total: 0.2436
# Epoch 5/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - contrastive: 1.0878 - gate_entropy: 0.3284 - gate_mean: 0.7901 - gate_std: 0.2532 - lambda_unlearn: 0.3042 - sigma: 1.0010 - total: 1.0881
# Epoch 6/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 241s 1s/step - contrastive: 0.4356 - gate_entropy: 0.3337 - gate_mean: 0.8022 - gate_std: 0.2305 - lambda_unlearn: 0.3043 - sigma: 1.0024 - total: 0.4360
# Epoch 7/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - contrastive: 0.2166 - gate_entropy: 0.3177 - gate_mean: 0.8001 - gate_std: 0.2462 - lambda_unlearn: 0.3053 - sigma: 1.0019 - total: 0.2169
# Epoch 8/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - contrastive: 0.6251 - gate_entropy: 0.3322 - gate_mean: 0.7940 - gate_std: 0.2357 - lambda_unlearn: 0.3062 - sigma: 1.0021 - total: 0.6254
# Epoch 9/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - contrastive: 0.4457 - gate_entropy: 0.3386 - gate_mean: 0.8141 - gate_std: 0.2195 - lambda_unlearn: 0.3067 - sigma: 1.0030 - total: 0.4461
# Epoch 10/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 228s 1s/step - contrastive: 0.3197 - gate_entropy: 0.2934 - gate_mean: 0.7895 - gate_std: 0.2713 - lambda_unlearn: 0.3081 - sigma: 1.0030 - total: 0.3199
# Epoch 11/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.1659 - gate_entropy: 0.3264 - gate_mean: 0.7767 - gate_std: 0.2669 - lambda_unlearn: 0.3093 - sigma: 1.0031 - total: 0.1662
# Epoch 12/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.6238 - gate_entropy: 0.3405 - gate_mean: 0.7733 - gate_std: 0.2718 - lambda_unlearn: 0.3099 - sigma: 1.0033 - total: 0.6242
# Epoch 13/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4162 - gate_entropy: 0.3174 - gate_mean: 0.8128 - gate_std: 0.2352 - lambda_unlearn: 0.3102 - sigma: 1.0042 - total: 0.4165
# Epoch 14/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3011 - gate_entropy: 0.3322 - gate_mean: 0.7715 - gate_std: 0.2611 - lambda_unlearn: 0.3114 - sigma: 1.0040 - total: 0.3014
# Epoch 15/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.6316 - gate_entropy: 0.3250 - gate_mean: 0.7585 - gate_std: 0.2906 - lambda_unlearn: 0.3128 - sigma: 1.0035 - total: 0.6319
# Epoch 16/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.2038 - gate_entropy: 0.3813 - gate_mean: 0.7502 - gate_std: 0.2497 - lambda_unlearn: 0.3130 - sigma: 1.0042 - total: 0.2042
# Epoch 17/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3164 - gate_entropy: 0.3255 - gate_mean: 0.7981 - gate_std: 0.2382 - lambda_unlearn: 0.3140 - sigma: 1.0044 - total: 0.3167
# Epoch 18/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.4227 - gate_entropy: 0.3138 - gate_mean: 0.7845 - gate_std: 0.2686 - lambda_unlearn: 0.3155 - sigma: 1.0038 - total: 0.4230
# Epoch 19/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.0954 - gate_entropy: 0.3409 - gate_mean: 0.7823 - gate_std: 0.2539 - lambda_unlearn: 0.3160 - sigma: 1.0045 - total: 0.0957
# Epoch 20/20
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 227s 1s/step - contrastive: 0.3083 - gate_entropy: 0.3724 - gate_mean: 0.7134 - gate_std: 0.2863 - lambda_unlearn: 0.3175 - sigma: 1.0041 - total: 0.3086

# %%
#===============================================================
# SAVE ENCODER
# ===============================================================
model.enc.save("MV2_Encoder_alpha75_160image_epoch60.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
print(type(enc))
print(hasattr(enc, '_is_graph_network'), getattr(enc, '_is_graph_network', None))
# Out:
# <class 'keras.src.models.functional.Functional'>
# False None

# %%
# ===============================================================
# LINEAR EVALUATION
# ===============================================================
enc.trainable = False # Freeze encoder for linear evaluation

clf = tf.keras.Sequential([
    layers.Input((IMG_SIZE, IMG_SIZE, 3)),
    enc,
    layers.Dense(len(TARGET_CLASSES), activation='softmax')
])

clf.compile(optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy'])

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train = datagen.flow_from_directory(
    TARGET_DIR, target_size=(IMG_SIZE, IMG_SIZE),
    subset='training', class_mode='categorical',
    classes=TARGET_CLASSES # Explicitly set classes for the generator
)

val = datagen.flow_from_directory(
    TARGET_DIR, target_size=(IMG_SIZE, IMG_SIZE),
    subset='validation', class_mode='categorical',
    classes=TARGET_CLASSES # Explicitly set classes for the generator
)

clf.fit(train, validation_data=val, epochs=40) # Keeping 40 epochs for linear eval

loss, acc = clf.evaluate(val)
print(f"\n🎯 Final Accuracy with stronger settings: {acc*100:.2f}%")
# Out:
# Found 442 images belonging to 3 classes.
# Found 110 images belonging to 3 classes.
# Epoch 1/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.4276 - loss: 1.2379 - val_accuracy: 0.4818 - val_loss: 1.3455
# Epoch 2/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.5385 - loss: 1.0512 - val_accuracy: 0.5182 - val_loss: 1.2046
# Epoch 3/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6041 - loss: 0.9206 - val_accuracy: 0.5636 - val_loss: 1.0982
# Epoch 4/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.6697 - loss: 0.8192 - val_accuracy: 0.6182 - val_loss: 1.0233
# Epoch 5/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.6968 - loss: 0.7513 - val_accuracy: 0.6091 - val_loss: 0.9638
# Epoch 6/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.7262 - loss: 0.7006 - val_accuracy: 0.6455 - val_loss: 0.9187
# Epoch 7/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7557 - loss: 0.6583 - val_accuracy: 0.6545 - val_loss: 0.8821
# Epoch 8/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7670 - loss: 0.6259 - val_accuracy: 0.6818 - val_loss: 0.8533
# Epoch 9/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.7783 - loss: 0.5995 - val_accuracy: 0.6909 - val_loss: 0.8242
# Epoch 10/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.7986 - loss: 0.5761 - val_accuracy: 0.6909 - val_loss: 0.8021
# Epoch 11/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.7986 - loss: 0.5560 - val_accuracy: 0.6818 - val_loss: 0.7787
# Epoch 12/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.8009 - loss: 0.5397 - val_accuracy: 0.6727 - val_loss: 0.7634
# Epoch 13/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8122 - loss: 0.5240 - val_accuracy: 0.6727 - val_loss: 0.7467
# Epoch 14/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8145 - loss: 0.5109 - val_accuracy: 0.6727 - val_loss: 0.7322
# Epoch 15/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8145 - loss: 0.4997 - val_accuracy: 0.6818 - val_loss: 0.7199
# Epoch 16/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.8190 - loss: 0.4884 - val_accuracy: 0.6909 - val_loss: 0.7103
# Epoch 17/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.8258 - loss: 0.4796 - val_accuracy: 0.6818 - val_loss: 0.6979
# Epoch 18/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8258 - loss: 0.4705 - val_accuracy: 0.6909 - val_loss: 0.6902
# Epoch 19/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8303 - loss: 0.4633 - val_accuracy: 0.7000 - val_loss: 0.6816
# Epoch 20/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8348 - loss: 0.4567 - val_accuracy: 0.7000 - val_loss: 0.6745
# Epoch 21/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.8348 - loss: 0.4504 - val_accuracy: 0.7091 - val_loss: 0.6705
# Epoch 22/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8371 - loss: 0.4445 - val_accuracy: 0.7273 - val_loss: 0.6603
# Epoch 23/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.8348 - loss: 0.4393 - val_accuracy: 0.7364 - val_loss: 0.6606
# Epoch 24/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.8394 - loss: 0.4343 - val_accuracy: 0.7182 - val_loss: 0.6545
# Epoch 25/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8394 - loss: 0.4307 - val_accuracy: 0.7273 - val_loss: 0.6497
# Epoch 26/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8394 - loss: 0.4261 - val_accuracy: 0.7182 - val_loss: 0.6440
# Epoch 27/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8371 - loss: 0.4214 - val_accuracy: 0.7364 - val_loss: 0.6399
# Epoch 28/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8394 - loss: 0.4183 - val_accuracy: 0.7364 - val_loss: 0.6371
# Epoch 29/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8439 - loss: 0.4151 - val_accuracy: 0.7364 - val_loss: 0.6312
# Epoch 30/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8462 - loss: 0.4119 - val_accuracy: 0.7273 - val_loss: 0.6248
# Epoch 31/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8484 - loss: 0.4085 - val_accuracy: 0.7364 - val_loss: 0.6233
# Epoch 32/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8507 - loss: 0.4053 - val_accuracy: 0.7364 - val_loss: 0.6202
# Epoch 33/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8529 - loss: 0.4027 - val_accuracy: 0.7273 - val_loss: 0.6176
# Epoch 34/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.8507 - loss: 0.4000 - val_accuracy: 0.7273 - val_loss: 0.6141
# Epoch 35/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.8529 - loss: 0.3974 - val_accuracy: 0.7273 - val_loss: 0.6114
# Epoch 36/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8529 - loss: 0.3952 - val_accuracy: 0.7455 - val_loss: 0.6059
# Epoch 37/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8552 - loss: 0.3933 - val_accuracy: 0.7273 - val_loss: 0.6081
# Epoch 38/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8529 - loss: 0.3913 - val_accuracy: 0.7455 - val_loss: 0.6066
# Epoch 39/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8552 - loss: 0.3889 - val_accuracy: 0.7364 - val_loss: 0.5987
# Epoch 40/40
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.8529 - loss: 0.3864 - val_accuracy: 0.7455 - val_loss: 0.5957
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7455 - loss: 0.5957
#
# 🎯 Final Accuracy with stronger settings: 74.55%

# %%
loss, acc = clf.evaluate(val)
print(f"\n🎯 Final Accuracy with stronger settings: {acc*100:.2f}%")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7455 - loss: 0.5957
#
# 🎯 Final Accuracy with stronger settings: 74.55%

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Pull all batches from the val generator into arrays
X_val_list, y_val_list = [], []
val.reset()   # make sure we start from the beginning
steps = len(val)   # number of batches in one full pass
for i in range(steps):
    xb, yb = next(val)
    X_val_list.append(xb)
    y_val_list.append(yb)

X_val = np.concatenate(X_val_list, axis=0)
y_val = np.concatenate(y_val_list, axis=0)

embeddings = model.enc.predict(X_val, batch_size=32)
labels = np.argmax(y_val, axis=1)

tsne = TSNE(n_components=2, random_state=42)
emb_2d = tsne.fit_transform(embeddings)

plt.figure(figsize=(8,6))
for c in range(len(TARGET_CLASSES)):
    mask = labels == c
    plt.scatter(emb_2d[mask,0], emb_2d[mask,1], label=TARGET_CLASSES[c], alpha=0.6)
plt.legend()
plt.title("t-SNE of 96px encoder embeddings")
plt.savefig("tsne_96px.png", dpi=150)
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x714ea62a3130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x714ea62a3130> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step

# %%
# ===============================================================
# FP32 RESULTS
# ===============================================================
clf.save("full_da_model_alpha75_image160_FP32_epoch60.h5")

fp32_size = os.path.getsize(
    "full_da_model_alpha75_image160_FP32_epoch60.h5"
) / (1024 * 1024)

print("\n===== FP32 =====")
print(f"Accuracy : {acc*100:.2f}%")
print(f"Size     : {fp32_size:.2f} MB")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== FP32 =====
# Accuracy : 74.55%
# Size     : 5.96 MB

# %%
# ===============================================================
# INT8 PTQ
# ===============================================================
def representative_data_gen():

    count = 0

    for images, _ in train:

        for img in images:

            yield [np.expand_dims(
                img.astype(np.float32),
                axis=0
            )]

            count += 1

            if count >= 300:
                return


converter = tf.lite.TFLiteConverter.from_keras_model(clf)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

converter.representative_dataset = representative_data_gen

converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS_INT8
]

converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

tflite_model = converter.convert()

with open("full_da_model75_image160_e60_int8_ptq.tflite", "wb") as f:
    f.write(tflite_model)

ptq_size = os.path.getsize(
    "full_da_model75_image160_e60_int8_ptq.tflite"
) / (1024 * 1024)

print("\n===== INT8 PTQ =====")
print(f"Size : {ptq_size:.2f} MB")
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmphh7n0e1f/assets
# INFO:tensorflow:Assets written to: /tmp/tmphh7n0e1f/assets
# Saved artifact at '/tmp/tmphh7n0e1f'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name='keras_tensor_1854')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   124583111765584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124587954596048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124603700986272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124598688251424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124603687009120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124603698910432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124587954589712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124603698913776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124580054476128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300149344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124603698912720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300154624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300153392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300148288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300161488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300149168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300149696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300151104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300164304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300148640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300155680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300158496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300153216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300160608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300157264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300162016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828630048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828619488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585300151280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828629520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828620368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828620720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828619312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828618784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828622656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828627408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828625824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828616144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828628640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828625472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828624592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828623712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828617728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828624768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828621952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828615968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909577312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828621072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585828615616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909571856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909574144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909577840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909575904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909566224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909566928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909566752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909578720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909571680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909578896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909577488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909576080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909577136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909576960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909568336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909574848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909570272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834016688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834020032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834004896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834019504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834019856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834017216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834013520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834005072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834008416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834010176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834008064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834012288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834018624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834012464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834010000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834012640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834006832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834008592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834017744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585834007888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303994816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303996400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303997280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303986544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303995344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303988832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303997632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303986192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303985136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303997456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899228096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899232848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124585303992352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899236192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899234784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899233024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899242528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899238128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899235312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899230208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899227568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899236016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899227040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899239536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899240064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899239712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899242176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899231968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899235488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914452880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914454288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899229680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914451120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914461856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914463264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914458864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914451472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914447424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914447776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914460800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914450064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914461152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914455168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914454992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914455872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914456752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914453232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914453936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914453584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914459744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914453408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111704816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586914448656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909590176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909594928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909590880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909585600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909595632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909595456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909594576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909583312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909585248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909593872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909592816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909582608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909588416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909585424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909581376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909590528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909582080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909589296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909590000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586909583488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241256000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241257056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241254768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241249136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241246144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241247200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241255296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241255648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241255472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241248256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241257760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241256352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241258112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241257584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241251424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241254240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241253360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586921722976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599273637488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599273643472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241252480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599273639776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599273636256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599273639248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599241259872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599244829296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599244818032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124599244828240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899964144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899974704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899968544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899967840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899971536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899979984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899965376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899974880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899978752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899968368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899969424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899977872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899978048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899975056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899978400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899979808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899971360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586899972416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907853120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907852592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907856464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907860512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907859280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907849424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907850304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907852768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907859808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907859456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907846960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907852064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907856816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907852944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907848368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907852416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907848544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907853824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907845376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586907856288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894275360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894277296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894425104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894413664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894418592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894420880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894419296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111419760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111418528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111415184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111420640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111415008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111415360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111415712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111421520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111425744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111390688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111382944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111418880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111391392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111387696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111390336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111416240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111391744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111383120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124583111386816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894806176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894811984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894806528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894805472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894807232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894817792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894803536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894811104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894811632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894813568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894808288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124586894807408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124579907282976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   124582611916352: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages/tensorflow/lite/python/convert.py:846: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# W0000 00:00:1783836728.642346  320409 tf_tfl_flatbuffer_helpers.cc:364] Ignored output_format.
# W0000 00:00:1783836728.642360  320409 tf_tfl_flatbuffer_helpers.cc:367] Ignored drop_control_dependency.
# I0000 00:00:1783836728.642461  320409 reader.cc:83] Reading SavedModel from: /tmp/tmphh7n0e1f
# I0000 00:00:1783836728.649147  320409 reader.cc:52] Reading meta graph with tags { serve }
# I0000 00:00:1783836728.649156  320409 reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmphh7n0e1f
# I0000 00:00:1783836728.704750  320409 loader.cc:236] Restoring SavedModel bundle.
# I0000 00:00:1783836729.017341  320409 loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmphh7n0e1f
# I0000 00:00:1783836729.088585  320409 loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 446132 microseconds.
# ===== INT8 PTQ =====
# Size : 1.77 MB
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: INT8
# W0000 00:00:1783836732.821447  320409 flatbuffer_export.cc:3851] Skipping runtime version metadata in the model. This will be generated by the exporter.

# %%
import tensorflow_model_optimization as tfmot
print(tfmot.__version__)
# Out:
# 0.8.1

# %%
# ===============================================================
# TFLITE ACCURACY EVALUATION
# ===============================================================
import numpy as np
import tensorflow as tf

def evaluate_tflite(model_path, val_gen):
    interpreter = tf.lite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    correct = 0
    total = 0

    val_gen.reset()

    for _ in range(len(val_gen)):
        x_batch, y_batch = next(val_gen)

        for i in range(len(x_batch)):
            x = x_batch[i:i+1]

            # INT8 quantization parameters
            input_scale, input_zero_point = \
                input_details[0]['quantization']

            x_int8 = (x / input_scale + input_zero_point)
            x_int8 = np.clip(x_int8, -128, 127).astype(np.int8)

            interpreter.set_tensor(
                input_details[0]['index'],
                x_int8
            )

            interpreter.invoke()

            output = interpreter.get_tensor(
                output_details[0]['index']
            )

            # dequantize output
            output_scale, output_zero_point = \
                output_details[0]['quantization']

            output = (
                output.astype(np.float32) - output_zero_point
            ) * output_scale

            pred = np.argmax(output)
            true = np.argmax(y_batch[i])

            correct += int(pred == true)
            total += 1

    acc = correct / total
    print(f"TFLite Accuracy: {acc*100:.2f}%")

    return acc

# %%
ptq_acc = evaluate_tflite('full_da_model75_image160_int8_ptq.tflite', val)
# Out:
# TFLite Accuracy: 73.64%

# %%
interpreter = tf.lite.Interpreter(
    model_path="full_da_model_int8_ptq.tflite"
)

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(input_details[0]["dtype"])
print(output_details[0]["dtype"])
# Out:
# <class 'numpy.int8'>
# <class 'numpy.int8'>

# %%
print("\n==============================")
print(f"FP32 Accuracy     : {acc*100:.2f}%")
print(f"FP32 Size         : {fp32_size:.2f} MB")
print("------------------------------")
# print(f"QAT Accuracy      : {qat_acc*100:.2f}%")
# print(f"QAT Size          : {qat_size:.2f} MB")
print("------------------------------")
print(f"PTQ Accuracy     : {ptq_acc*100:.2f}%")
print(f"INT8 PTQ Size     : {ptq_size:.2f} MB")
# print(f"QAT+INT8 Size     : {qat_int8_size:.2f} MB")
print("==============================")
# Out:
# ==============================
# FP32 Accuracy     : 74.55%
# FP32 Size         : 5.96 MB
# ------------------------------
# ------------------------------
# PTQ Accuracy     : 73.64%
# INT8 PTQ Size     : 1.77 MB
# ==============================

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize
from statsmodels.stats.contingency_tables import mcnemar
import os

plt.rcParams.update({
    'font.size': 11,
    'font.family': 'sans-serif',
    'axes.spines.top': False,
    'axes.spines.right': False,
    'figure.dpi': 150
})

OUTPUT_DIR = "paper_figures"
os.makedirs(OUTPUT_DIR, exist_ok=True)
CLASS_NAMES = TARGET_CLASSES   # e.g. ['Bacterial Leaf Blight', 'Blast', 'Brown Spot']
COLORS = ['#4C72B0', '#DD8452', '#55A868']

# ===============================================================
# 1. TRAINING CURVES (accuracy + loss, train vs val)
# ===============================================================
def plot_training_curves(history, save_name="training_curves.png"):
    fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

    axes[0].plot(history.history['accuracy'], label='Train', color=COLORS[0], linewidth=2)
    axes[0].plot(history.history['val_accuracy'], label='Validation', color=COLORS[1], linewidth=2)
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].legend(frameon=False)
    axes[0].grid(alpha=0.3)

    axes[1].plot(history.history['loss'], label='Train', color=COLORS[0], linewidth=2)
    axes[1].plot(history.history['val_loss'], label='Validation', color=COLORS[1], linewidth=2)
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].set_title('Training and Validation Loss')
    axes[1].legend(frameon=False)
    axes[1].grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()

# Usage: plot_training_curves(history)   # `history` from your clf.fit() call


# ===============================================================
# 2. CONFUSION MATRIX (nice heatmap, raw counts + normalized)
# ===============================================================
def plot_confusion_matrix(y_true, y_pred,
                          save_name="confusion_matrix.png",
                          title="Confusion Matrix"):

    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    sns.heatmap(
        cm,
        annot=True,
        fmt='d',
        cmap='Blues',
        cbar=False,
        xticklabels=CLASS_NAMES,
        yticklabels=CLASS_NAMES,
        ax=axes[0]
    )
    axes[0].set_title('Counts')
    axes[0].set_ylabel('True Label')
    axes[0].set_xlabel('Predicted Label')

    sns.heatmap(
        cm_norm,
        annot=True,
        fmt='.1%',
        cmap='Blues',
        cbar=False,
        xticklabels=CLASS_NAMES,
        yticklabels=CLASS_NAMES,
        ax=axes[1]
    )
    axes[1].set_title('Normalized')
    axes[1].set_ylabel('True Label')
    axes[1].set_xlabel('Predicted Label')

    # Single top title
    fig.suptitle(title, fontsize=16, fontweight='bold')

    plt.tight_layout(rect=[0, 0, 1, 0.95])

    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()

    return cm

# Usage:
# y_pred_probs = clf.predict(X_val)
# y_pred = np.argmax(y_pred_probs, axis=1)
# y_true = np.argmax(y_val, axis=1)
# plot_confusion_matrix(y_true, y_pred)


# ===============================================================
# 3. PER-CLASS METRICS BAR CHART (precision / recall / F1)
# ===============================================================
def plot_per_class_metrics(y_true, y_pred, save_name="per_class_metrics.png"):
    report = classification_report(y_true, y_pred, target_names=CLASS_NAMES, output_dict=True)

    metrics = ['precision', 'recall', 'f1-score']
    x = np.arange(len(CLASS_NAMES))
    width = 0.25

    fig, ax = plt.subplots(figsize=(8, 5))
    for i, metric in enumerate(metrics):
        values = [report[cls][metric] for cls in CLASS_NAMES]
        ax.bar(x + i*width, values, width, label=metric.capitalize())

    ax.set_xticks(x + width)
    ax.set_xticklabels(CLASS_NAMES)
    ax.set_ylabel('Score')
    ax.set_ylim(0, 1.05)
    ax.set_title('Per-Class Precision, Recall, and F1-Score')
    ax.legend(frameon=False)
    ax.grid(alpha=0.3, axis='y')

    plt.tight_layout()
    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()
    return report

# Usage: plot_per_class_metrics(y_true, y_pred)


# ===============================================================
# 4. ROC CURVES (one-vs-rest, per class + micro-average)
# ===============================================================
def plot_roc_curves(y_true, y_pred_probs, save_name="roc_curves.png"):
    n_classes = len(CLASS_NAMES)
    y_true_bin = label_binarize(y_true, classes=range(n_classes))

    fig, ax = plt.subplots(figsize=(6.5, 6))
    for i in range(n_classes):
        fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
        roc_auc = auc(fpr, tpr)
        ax.plot(fpr, tpr, color=COLORS[i], linewidth=2,
                label=f'{CLASS_NAMES[i]} (AUC = {roc_auc:.3f})')

    ax.plot([0, 1], [0, 1], 'k--', alpha=0.4, label='Chance')
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('ROC-AUC Curve')
    ax.legend(loc='lower right', frameon=False, fontsize=9)
    ax.grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()

# Usage: plot_roc_curves(y_true, y_pred_probs)


# ===============================================================
# 5. FP32 vs INT8 STATISTICAL COMPARISON (McNemar's test)
# — the standard test for "are these two models' predictions
#   significantly different?" on the SAME test samples
# ===============================================================
def mcnemar_comparison(y_true, y_pred_fp32, y_pred_int8):
    correct_fp32 = (y_pred_fp32 == y_true)
    correct_int8 = (y_pred_int8 == y_true)

    # Build 2x2 contingency table
    both_correct = np.sum(correct_fp32 & correct_int8)
    only_fp32_correct = np.sum(correct_fp32 & ~correct_int8)
    only_int8_correct = np.sum(~correct_fp32 & correct_int8)
    both_wrong = np.sum(~correct_fp32 & ~correct_int8)

    table = [[both_correct, only_fp32_correct],
             [only_int8_correct, both_wrong]]

    result = mcnemar(table, exact=True)

    print("McNemar's Test: FP32 vs INT8 Predictions")
    print(f"  Both correct        : {both_correct}")
    print(f"  Only FP32 correct   : {only_fp32_correct}")
    print(f"  Only INT8 correct   : {only_int8_correct}")
    print(f"  Both incorrect      : {both_wrong}")
    print(f"  Statistic           : {result.statistic:.4f}")
    print(f"  p-value             : {result.pvalue:.4f}")

    if result.pvalue < 0.05:
        print("  → Statistically significant difference between FP32 and INT8 (p < 0.05)")
    else:
        print("  → No statistically significant difference between FP32 and INT8 (p ≥ 0.05)")

    return result

# Usage:
# y_pred_fp32 = np.argmax(clf.predict(X_val), axis=1)
# y_pred_int8 = ...  # from your evaluate_tflite() function
# mcnemar_comparison(y_true, y_pred_fp32, y_pred_int8)


# ===============================================================
# 6. MODEL SIZE vs ACCURACY TRADE-OFF (your whole day's journey!)
# — genuinely valuable for the paper: shows deliberate,
#   justified architecture search, not just one result
# ===============================================================
def plot_accuracy_size_tradeoff(save_name="accuracy_size_tradeoff.png"):
    # Fill in with your actual recorded results from today
    configs = [
        {"name": "MobileNetV3S\n(224px)", "acc": 90.99, "size_mb": 1.25, "note": "PTQ failed"},
        {"name": "MobileNetV2\n(224px, α=1.0)", "acc": 66.02, "size_mb": 2.5},
        {"name": "MobileNetV2\n(96px, α=0.75)", "acc": 66.99, "size_mb": None},
        {"name": "MobileNetV2\n(128px, α=0.75)", "acc": 78.64, "size_mb": None},
        {"name": "MobileNetV2\n(160px, α=0.75)", "acc": 80.58, "size_mb": 1.6},
        {"name": "MobileNetV2\n(160px, α=0.5)", "acc": 72.82, "size_mb": None},
    ]
    names = [c["name"] for c in configs]
    accs = [c["acc"] for c in configs]

    fig, ax = plt.subplots(figsize=(9, 5))
    bars = ax.bar(names, accs, color=COLORS[0], alpha=0.85)
    ax.set_ylabel('Test Accuracy (%)')
    ax.set_title('Architecture Search: Accuracy Across Configurations')
    ax.set_ylim(0, 100)
    ax.grid(alpha=0.3, axis='y')

    # Highlight the chosen final model
    bars[4].set_color(COLORS[2])   # 160px, alpha=0.75 — your final choice

    plt.xticks(rotation=15, ha='right')
    plt.tight_layout()
    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()

plot_accuracy_size_tradeoff()

# %%
import tensorflow as tf
import numpy as np

IMG_SIZE = 160
NUM_CLASSES = 3
TARGET_CLASSES = ['Bacterial Leaf Blight', 'Blast', 'Brown Spot']   # match your actual order

# ===============================================================
# Load the complete trained classifier directly
# ===============================================================
clf = tf.keras.models.load_model("full_da_model_alpha75_image160_FP32.h5", compile=False)
clf.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# ===============================================================
# Load your validation data
# (adjust to however you originally loaded it — X_val/y_val numpy arrays,
# or pull from a generator if that's what this notebook uses)
# ===============================================================
y_pred_probs = clf.predict(X_val, batch_size=32)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_val, axis=1)

print(f"Loaded {len(X_val)} validation samples")
print(f"FP32 accuracy check: {(y_pred == y_true).mean()*100:.2f}%")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step
# Loaded 110 validation samples
# FP32 accuracy check: 74.55%

# %%
plot_confusion_matrix(y_true, y_pred)
plot_per_class_metrics(y_true, y_pred)
plot_roc_curves(y_true, y_pred_probs)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_5fold_training_curves(all_histories, save_name="5fold_training_curves.png"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    max_epochs = max(len(h['val_accuracy']) for h in all_histories)

    # Individual fold curves (light, semi-transparent)
    for i, h in enumerate(all_histories):
        axes[0].plot(h['val_accuracy'], alpha=0.35, color='#4C72B0', linewidth=1)
        axes[1].plot(h['val_loss'], alpha=0.35, color='#4C72B0', linewidth=1)

    # Mean curve across folds (padded/truncated to equal length if needed)
    val_acc_matrix = np.array([h['val_accuracy'][:max_epochs] for h in all_histories
                                 if len(h['val_accuracy']) == max_epochs])
    val_loss_matrix = np.array([h['val_loss'][:max_epochs] for h in all_histories
                                  if len(h['val_loss']) == max_epochs])

    mean_val_acc = val_acc_matrix.mean(axis=0)
    mean_val_loss = val_loss_matrix.mean(axis=0)

    axes[0].plot(mean_val_acc, color='#DD8452', linewidth=2.5, label='Mean (5-fold)')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Validation Accuracy')
    axes[0].set_title('Validation Accuracy Across 5 Folds')
    axes[0].legend(frameon=False)
    axes[0].grid(alpha=0.3)

    axes[1].plot(mean_val_loss, color='#DD8452', linewidth=2.5, label='Mean (5-fold)')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Validation Loss')
    axes[1].set_title('Validation Loss Across 5 Folds')
    axes[1].legend(frameon=False)
    axes[1].grid(alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{OUTPUT_DIR}/{save_name}", bbox_inches='tight')
    plt.show()

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import layers, models
from sklearn.metrics import confusion_matrix

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

all_y_true = []
all_y_pred = []
all_y_pred_probs = []
all_histories = []

for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X_all, y_all_int)):
    print(f"\n{'='*50}\nFold {fold_idx+1}/5\n{'='*50}")

    X_tr, X_va = X_all[train_idx], X_all[val_idx]
    y_tr = tf.keras.utils.to_categorical(y_all_int[train_idx], NUM_CLASSES)
    y_va = tf.keras.utils.to_categorical(y_all_int[val_idx], NUM_CLASSES)
    y_va_int = y_all_int[val_idx]

    x = encoder.output
    x = layers.Dense(NUM_CLASSES, activation='softmax', name='clf_head')(x)
    clf = models.Model(inputs=encoder.input, outputs=x)
    clf.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    history = clf.fit(X_tr, y_tr, validation_data=(X_va, y_va),
                       epochs=EPOCHS_PER_FOLD, batch_size=BATCH_SIZE, verbose=0)
    all_histories.append(history.history)

    probs = clf.predict(X_va, verbose=0)
    preds = np.argmax(probs, axis=1)

    all_y_true.extend(y_va_int)
    all_y_pred.extend(preds)
    all_y_pred_probs.append(probs)

    fold_acc = (preds == y_va_int).mean()
    print(f"Fold {fold_idx+1} done — {len(val_idx)} samples, accuracy: {fold_acc*100:.2f}%")

all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)
all_y_pred_probs = np.concatenate(all_y_pred_probs, axis=0)

print(f"\nCombined out-of-fold accuracy: {(all_y_true == all_y_pred).mean()*100:.2f}%")

# ===============================================================
# Combined confusion matrix
# ===============================================================
plot_confusion_matrix(all_y_true, all_y_pred, save_name="confusion_matrix_5fold_combined.png",
                       title="Confusion Matrix (5-Fold Combined)")

# ===============================================================
# Combined ROC curves
# ===============================================================
plot_roc_curves(all_y_true, all_y_pred_probs, save_name="roc_curves_5fold_combined.png")

# ===============================================================
# Validation accuracy/loss curves across folds
# ===============================================================
plot_5fold_training_curves(all_histories)
# Out:
# ==================================================
# Fold 1/5
# ==================================================
# Fold 1 done — 111 samples, accuracy: 79.28%
#
# ==================================================
# Fold 2/5
# ==================================================
# Fold 2 done — 111 samples, accuracy: 83.78%
#
# ==================================================
# Fold 3/5
# ==================================================
# Fold 3 done — 110 samples, accuracy: 81.82%
#
# ==================================================
# Fold 4/5
# ==================================================
# Fold 4 done — 110 samples, accuracy: 80.00%
#
# ==================================================
# Fold 5/5
# ==================================================

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from statsmodels) (2.3.3)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from statsmodels) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2026.2)
# Requirement already satisfied: six>=1.5 in /home/iot-lab/miniconda3/envs/leafenv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Downloading statsmodels-0.14.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 10.5 MB/s  0:00:00eta 0:00:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, statsmodels
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [statsmodels] [statsmodels]
# Successfully installed patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
from PIL import Image

TARGET_DIR = '/media/iot-lab/Projects/Nazifa/Unlearning/feature_unlearning/RiceDiseases-DataSet'

def load_target_images_from_nested(target_dir, img_size=160):   # match your IMG_SIZE
    VALID_EXTENSIONS = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.tif'}
    class_names = sorted([
        d for d in os.listdir(target_dir)
        if os.path.isdir(os.path.join(target_dir, d)) and not d.startswith('.')
    ])
    images, labels = [], []
    for label_idx, class_name in enumerate(class_names):
        class_path = os.path.join(target_dir, class_name)
        for subfolder in os.listdir(class_path):
            subfolder_path = os.path.join(class_path, subfolder)
            if not os.path.isdir(subfolder_path):
                continue
            for fname in os.listdir(subfolder_path):
                ext = os.path.splitext(fname)[1].lower()
                if ext not in VALID_EXTENSIONS:
                    continue
                fpath = os.path.join(subfolder_path, fname)
                try:
                    img = Image.open(fpath).convert('RGB')
                    img = img.resize((img_size, img_size))
                    images.append(np.array(img))
                    labels.append(label_idx)
                except Exception as e:
                    print(f"Skipping {fpath}: {e}")
    return np.array(images), np.array(labels), class_names

target_images, target_labels, TARGET_CLASSES = load_target_images_from_nested(TARGET_DIR, img_size=160)

X_all = target_images.astype(np.float32) / 255.0
y_all_int = target_labels

print(f"Loaded {len(X_all)} total images across {len(TARGET_CLASSES)} classes")
print(f"Class distribution: {[(TARGET_CLASSES[i], (y_all_int==i).sum()) for i in range(len(TARGET_CLASSES))]}")
# Out:
# Loaded 552 total images across 3 classes
# Class distribution: [('Bacterial leaf blight', np.int64(192)), ('blast', np.int64(160)), ('brownspot', np.int64(200))]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import matplotlib.pyplot as plt

# ===============================================================
# Load your trained, frozen encoder (feature extraction only —
# no need to retrain the encoder per fold, only the classifier head)
# ===============================================================
encoder = tf.keras.models.load_model('MV2_Encoder_alpha75_160image_Jul11.h5', compile=False)
encoder.trainable = False

# X_all, y_all_int = your full labeled target dataset (images + integer labels),
# NOT pre-split into train/val — 5-fold CV needs the whole pool
# (recombine your earlier X_train+X_val, y_train+y_val if needed:)
# X_all = np.concatenate([X_train, X_val], axis=0)
# y_all_int = np.concatenate([np.argmax(y_train,1), np.argmax(y_val,1)], axis=0)

NUM_CLASSES = 3
EPOCHS_PER_FOLD = 40
BATCH_SIZE = 32

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_accuracies = []
fold_precisions = []
fold_recalls = []
fold_f1s = []

for fold_idx, (train_idx, val_idx) in enumerate(skf.split(X_all, y_all_int)):
    print(f"\n{'='*50}\nFold {fold_idx+1}/5\n{'='*50}")

    X_tr, X_va = X_all[train_idx], X_all[val_idx]
    y_tr = tf.keras.utils.to_categorical(y_all_int[train_idx], NUM_CLASSES)
    y_va = tf.keras.utils.to_categorical(y_all_int[val_idx], NUM_CLASSES)

    # Fresh classifier head each fold, same frozen encoder
    x = encoder.output
    x = layers.Dense(NUM_CLASSES, activation='softmax', name='clf_head')(x)
    clf = models.Model(inputs=encoder.input, outputs=x)
    clf.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    clf.fit(X_tr, y_tr, validation_data=(X_va, y_va),
            epochs=EPOCHS_PER_FOLD, batch_size=BATCH_SIZE, verbose=0)

    y_pred = np.argmax(clf.predict(X_va, verbose=0), axis=1)
    y_true = np.argmax(y_va, axis=1)

    acc = accuracy_score(y_true, y_pred)
    prec, rec, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted')

    fold_accuracies.append(acc)
    fold_precisions.append(prec)
    fold_recalls.append(rec)
    fold_f1s.append(f1)

    print(f"Fold {fold_idx+1} — Acc: {acc*100:.2f}%, Precision: {prec:.3f}, Recall: {rec:.3f}, F1: {f1:.3f}")

# ===============================================================
# Summary statistics
# ===============================================================
print(f"\n{'='*50}\n5-Fold CV Summary\n{'='*50}")
print(f"Accuracy : {np.mean(fold_accuracies)*100:.2f}% ± {np.std(fold_accuracies)*100:.2f}%")
print(f"Precision: {np.mean(fold_precisions):.3f} ± {np.std(fold_precisions):.3f}")
print(f"Recall   : {np.mean(fold_recalls):.3f} ± {np.std(fold_recalls):.3f}")
print(f"F1-score : {np.mean(fold_f1s):.3f} ± {np.std(fold_f1s):.3f}")

# ===============================================================
# Plot: per-fold accuracy with mean line
# ===============================================================
fig, ax = plt.subplots(figsize=(7, 5))
ax.bar(range(1, 6), [a*100 for a in fold_accuracies], color='#4C72B0', alpha=0.85)
ax.axhline(np.mean(fold_accuracies)*100, color='#DD8452', linestyle='--',
           label=f'Mean: {np.mean(fold_accuracies)*100:.2f}%')
ax.set_xlabel('Fold')
ax.set_ylabel('Accuracy (%)')
ax.set_title('5-Fold Cross-Validation Accuracy')
ax.set_xticks(range(1, 6))
ax.legend(frameon=False)
ax.grid(alpha=0.3, axis='y')
plt.tight_layout()
plt.savefig('paper_figures/5fold_cv_accuracy.png', bbox_inches='tight')
plt.show()
# Out:
# ==================================================
# Fold 1/5
# ==================================================
# Fold 1 — Acc: 83.78%, Precision: 0.843, Recall: 0.838, F1: 0.840
#
# ==================================================
# Fold 2/5
# ==================================================
# Fold 2 — Acc: 85.59%, Precision: 0.861, Recall: 0.856, F1: 0.857
#
# ==================================================
# Fold 3/5
# ==================================================
# Fold 3 — Acc: 82.73%, Precision: 0.830, Recall: 0.827, F1: 0.826
#
# ==================================================
# Fold 4/5
# ==================================================
# Fold 4 — Acc: 80.00%, Precision: 0.807, Recall: 0.800, F1: 0.800
#
# ==================================================
# Fold 5/5
# ==================================================
# Fold 5 — Acc: 79.09%, Precision: 0.791, Recall: 0.791, F1: 0.791
#
# ==================================================
# 5-Fold CV Summary
# ==================================================
# Accuracy : 82.24% ± 2.40%
# Precision: 0.826 ± 0.025
# Recall   : 0.822 ± 0.024
# F1-score : 0.823 ± 0.025
